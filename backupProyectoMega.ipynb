-- %% [markdown]
-- # [PracticaMega]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PracticaMega]    Script Date: 24/06/2025 04:03:21 p. m. ******/
CREATE DATABASE [PracticaMega]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PracticaMega', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\PracticaMega.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PracticaMega_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\PracticaMega_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [PracticaMega] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PracticaMega].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PracticaMega] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PracticaMega] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PracticaMega] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PracticaMega] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PracticaMega] SET ARITHABORT OFF 
GO
ALTER DATABASE [PracticaMega] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [PracticaMega] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PracticaMega] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PracticaMega] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PracticaMega] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PracticaMega] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PracticaMega] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PracticaMega] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PracticaMega] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PracticaMega] SET  DISABLE_BROKER 
GO
ALTER DATABASE [PracticaMega] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PracticaMega] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PracticaMega] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PracticaMega] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PracticaMega] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PracticaMega] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PracticaMega] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PracticaMega] SET RECOVERY FULL 
GO
ALTER DATABASE [PracticaMega] SET  MULTI_USER 
GO
ALTER DATABASE [PracticaMega] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PracticaMega] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PracticaMega] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PracticaMega] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PracticaMega] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PracticaMega] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'PracticaMega', N'ON'
GO
ALTER DATABASE [PracticaMega] SET QUERY_STORE = ON
GO
ALTER DATABASE [PracticaMega] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ciudades]

-- %%
USE [PracticaMega]
GO

-- %%
/****** Object:  Table [dbo].[ciudades]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ciudades](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[estados_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[colonias]

-- %%
/****** Object:  Table [dbo].[colonias]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[colonias](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[ciudad_id] [int] NULL,
	[abrevCiudad] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contratos]

-- %%
/****** Object:  Table [dbo].[contratos]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contratos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[suscriptor_id] [int] NULL,
	[numero_contrato] [varchar](50) NOT NULL,
	[fecha_inicio] [datetime] NOT NULL,
	[fecha_fin] [datetime] NULL,
	[estado] [varchar](20) NULL,
	[precio_mensual] [decimal](10, 2) NOT NULL,
	[notas] [text] NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contratos_promociones]

-- %%
/****** Object:  Table [dbo].[contratos_promociones]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contratos_promociones](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[contrato_id] [int] NULL,
	[promocion_id] [int] NULL,
	[fecha_aplicacion] [datetime] NULL,
	[fecha_vencimiento] [datetime] NOT NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contratos_servicios]

-- %%
/****** Object:  Table [dbo].[contratos_servicios]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contratos_servicios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[contrato_id] [int] NULL,
	[servicio_id] [int] NULL,
	[paquete_id] [int] NULL,
	[descuento] [decimal](10, 2) NULL,
	[fecha_inicio] [datetime] NOT NULL,
	[fecha_fin] [datetime] NULL,
	[estado] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[estados]

-- %%
/****** Object:  Table [dbo].[estados]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[estados](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[abreviatura] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[facturas]

-- %%
/****** Object:  Table [dbo].[facturas]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[facturas](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[contrato_id] [int] NULL,
	[numero_factura] [varchar](50) NOT NULL,
	[periodo_inicio] [datetime] NOT NULL,
	[periodo_fin] [datetime] NOT NULL,
	[subtotal] [decimal](10, 2) NOT NULL,
	[descuentos] [decimal](10, 2) NULL,
	[impuestos] [decimal](10, 2) NULL,
	[total] [decimal](10, 2) NOT NULL,
	[fecha_vencimiento] [datetime] NOT NULL,
	[estado] [varchar](20) NULL,
	[fecha_emision] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pagos]

-- %%
/****** Object:  Table [dbo].[pagos]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pagos](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[factura_id] [int] NULL,
	[monto] [decimal](10, 2) NOT NULL,
	[metodo_pago] [varchar](50) NULL,
	[referencia] [varchar](100) NULL,
	[fecha_pago] [datetime] NULL,
	[estado] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[paquetes]

-- %%
/****** Object:  Table [dbo].[paquetes]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[paquetes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [text] NULL,
	[precio_total] [decimal](10, 2) NOT NULL,
	[descuento_porcentaje] [decimal](5, 2) NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[paquetes_servicios]

-- %%
/****** Object:  Table [dbo].[paquetes_servicios]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[paquetes_servicios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[paquete_id] [int] NULL,
	[servicio_id] [int] NULL,
	[cantidad] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[promociones]

-- %%
/****** Object:  Table [dbo].[promociones]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[promociones](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [text] NULL,
	[tipo_promocion] [varchar](50) NULL,
	[valor_descuento] [decimal](10, 2) NULL,
	[es_porcentaje] [bit] NULL,
	[duracion_meses] [int] NULL,
	[fecha_inicio] [datetime] NOT NULL,
	[fecha_fin] [datetime] NOT NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[servicios]

-- %%
/****** Object:  Table [dbo].[servicios]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[servicios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[tipo_servicio_id] [int] NULL,
	[velocidad] [varchar](50) NULL,
	[precio_base] [decimal](10, 2) NOT NULL,
	[descripcion] [text] NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[suscriptores]

-- %%
/****** Object:  Table [dbo].[suscriptores]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[suscriptores](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[alias] [varchar](100) NULL,
	[ciudad_id] [int] NOT NULL,
	[colonia_id] [int] NOT NULL,
	[estados_id] [int] NOT NULL,
	[correo ] [varchar](50) NOT NULL,
	[celular] [varchar](50) NULL,
	[tipo_suscriptor_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tipos_servicios]

-- %%
/****** Object:  Table [dbo].[tipos_servicios]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tipos_servicios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[sku] [varchar](12) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [text] NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tipos_suscriptores]

-- %%
/****** Object:  Table [dbo].[tipos_suscriptores]    Script Date: 24/06/2025 04:03:22 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tipos_suscriptores](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[codigo] [varchar](10) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[descripcion] [text] NULL,
	[descuento_porcentaje] [decimal](5, 2) NULL,
	[requiere_contrato_especial] [bit] NULL,
	[activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ciudades]

-- %%
SET IDENTITY_INSERT [dbo].[ciudades] ON 
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (1, N'Aguascalientes', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (2, N'Calvillo', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (3, N'Rincón de Romos', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (4, N'Jesús María', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (5, N'Pabellón de Arteaga', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (6, N'San José de Gracia', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (7, N'Tepezalá', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (8, N'El Llano', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (9, N'Cosío', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (10, N'Asientos', 1)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (11, N'Tijuana', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (12, N'Mexicali', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (13, N'Ensenada', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (14, N'Playas de Rosarito', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (15, N'Tecate', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (16, N'San Felipe', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (17, N'La Rumorosa', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (18, N'Valle de Guadalupe', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (19, N'Puerto Nuevo', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (20, N'El Sauzal', 2)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (21, N'La Paz', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (22, N'Cabo San Lucas', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (23, N'San José del Cabo', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (24, N'Loreto', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (25, N'Mulegé', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (26, N'Comondú', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (27, N'Santa Rosalía', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (28, N'Guerrero Negro', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (29, N'Todos Santos', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (30, N'Ciudad Constitución', 3)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (31, N'Campeche', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (32, N'Ciudad del Carmen', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (33, N'Champotón', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (34, N'Escárcega', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (35, N'Calkiní', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (36, N'Hecelchakán', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (37, N'Hopelchén', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (38, N'Palizada', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (39, N'Tenabo', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (40, N'Calakmul', 4)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (41, N'Tuxtla Gutiérrez', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (42, N'San Cristóbal de las Casas', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (43, N'Tapachula', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (44, N'Comitán de Domínguez', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (45, N'Palenque', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (46, N'Ocosingo', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (47, N'Villaflores', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (48, N'Tonalá', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (49, N'Pichucalco', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (50, N'Arriaga', 5)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (51, N'Chihuahua', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (52, N'Ciudad Juárez', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (53, N'Delicias', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (54, N'Parral', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (55, N'Cuauhtémoc', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (56, N'Nuevo Casas Grandes', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (57, N'Camargo', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (58, N'Jiménez', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (59, N'Bocoyna', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (60, N'Meoqui', 6)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (61, N'Saltillo', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (62, N'Torreón', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (63, N'Monclova', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (64, N'Piedras Negras', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (65, N'Acuña', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (66, N'Sabinas', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (67, N'Nueva Rosita', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (68, N'San Pedro', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (69, N'Frontera', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (70, N'Parras', 7)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (71, N'Colima', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (72, N'Manzanillo', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (73, N'Tecomán', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (74, N'Armería', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (75, N'Villa de Álvarez', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (76, N'Coquimatlán', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (77, N'Cuauhtémoc', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (78, N'Ixtlahuacán', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (79, N'Minatitlán', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (80, N'Comala', 8)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (81, N'Durango', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (82, N'Gómez Palacio', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (83, N'Lerdo', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (84, N'Santiago Papasquiaro', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (85, N'Guadalupe Victoria', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (86, N'El Salto', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (87, N'Pueblo Nuevo', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (88, N'Tlahualilo', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (89, N'Canatlán', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (90, N'Vicente Guerrero', 9)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (91, N'León', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (92, N'Irapuato', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (93, N'Celaya', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (94, N'Salamanca', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (95, N'Guanajuato', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (96, N'Pénjamo', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (97, N'San Francisco del Rincón', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (98, N'Dolores Hidalgo', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (99, N'San Miguel de Allende', 10)
GO

-- %%
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (100, N'Acámbaro', 10)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (101, N'Acapulco', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (102, N'Chilpancingo', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (103, N'Iguala', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (104, N'Zihuatanejo', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (105, N'Taxco', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (106, N'Tlapa de Comonfort', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (107, N'Ometepec', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (108, N'Ayutla de los Libres', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (109, N'Arcelia', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (110, N'Petatlán', 11)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (111, N'Pachuca', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (112, N'Tulancingo', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (113, N'Tizayuca', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (114, N'Huejutla', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (115, N'Ixmiquilpan', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (116, N'Actopan', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (117, N'Tepeji del Río', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (118, N'Tula de Allende', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (119, N'Mixquiahuala', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (120, N'Zimapán', 12)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (121, N'Guadalajara', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (122, N'Zapopan', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (123, N'Tlaquepaque', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (124, N'Tonalá', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (125, N'Puerto Vallarta', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (126, N'Tlajomulco de Zúñiga', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (127, N'El Salto', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (128, N'Chapala', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (129, N'Ocotlán', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (130, N'Tepatitlán', 13)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (131, N'Toluca', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (132, N'Ecatepec', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (133, N'Naucalpan', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (134, N'Nezahualcóyotl', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (135, N'Tlalnepantla', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (136, N'Chimalhuacán', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (137, N'Atizapán de Zaragoza', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (138, N'Cuautitlán Izcalli', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (139, N'Valle de Chalco', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (140, N'Texcoco', 14)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (141, N'Morelia', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (142, N'Uruapan', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (143, N'Zamora', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (144, N'Lázaro Cárdenas', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (145, N'Apatzingán', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (146, N'Pátzcuaro', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (147, N'Sahuayo', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (148, N'Zitácuaro', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (149, N'Hidalgo', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (150, N'La Piedad', 15)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (151, N'Cuernavaca', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (152, N'Jiutepec', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (153, N'Temixco', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (154, N'Cuautla', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (155, N'Yautepec', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (156, N'Emiliano Zapata', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (157, N'Xochitepec', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (158, N'Zacatepec', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (159, N'Jojutla', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (160, N'Tepoztlán', 16)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (161, N'Tepic', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (162, N'Bahía de Banderas', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (163, N'Santiago Ixcuintla', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (164, N'Compostela', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (165, N'Acaponeta', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (166, N'Tuxpan', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (167, N'Ixtlán del Río', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (168, N'Tecuala', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (169, N'Rosamorada', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (170, N'Ruiz', 17)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (171, N'Monterrey', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (172, N'Guadalupe', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (173, N'San Nicolás de los Garza', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (174, N'Apodaca', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (175, N'Santa Catarina', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (176, N'San Pedro Garza García', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (177, N'Escobedo', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (178, N'Cadereyta Jiménez', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (179, N'Linares', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (180, N'Sabinas Hidalgo', 18)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (181, N'Oaxaca de Juárez', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (182, N'Salina Cruz', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (183, N'Tuxtepec', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (184, N'Juchitán', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (185, N'Huajuapan de León', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (186, N'Puerto Escondido', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (187, N'Matías Romero', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (188, N'Miahuatlán', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (189, N'Tlaxiaco', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (190, N'Pinotepa Nacional', 19)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (191, N'Puebla', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (192, N'Tehuacán', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (193, N'San Martín Texmelucan', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (194, N'Atlixco', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (195, N'Cholula', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (196, N'Huauchinango', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (197, N'Izúcar de Matamoros', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (198, N'Teziutlán', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (199, N'Amozoc', 20)
GO

-- %%
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (200, N'Cuautlancingo', 20)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (201, N'Querétaro', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (202, N'San Juan del Río', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (203, N'Corregidora', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (204, N'El Marqués', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (205, N'Tequisquiapan', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (206, N'Cadereyta de Montes', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (207, N'Amealco', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (208, N'Jalpan de Serra', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (209, N'Landa de Matamoros', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (210, N'Pedro Escobedo', 21)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (211, N'Cancún', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (212, N'Playa del Carmen', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (213, N'Chetumal', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (214, N'Cozumel', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (215, N'Tulum', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (216, N'Akumal', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (217, N'Bacalar', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (218, N'Isla Mujeres', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (219, N'Puerto Morelos', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (220, N'Xcaret', 22)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (221, N'San Luis Potosí', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (222, N'Soledad de Graciano Sánchez', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (223, N'Ciudad Valles', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (224, N'Rioverde', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (225, N'Matehuala', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (226, N'Tamazunchale', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (227, N'Cárdenas', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (228, N'Ebano', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (229, N'Cedral', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (230, N'Mexquitic', 23)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (231, N'Culiacán', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (232, N'Mazatlán', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (233, N'Los Mochis', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (234, N'Guasave', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (235, N'Navolato', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (236, N'El Fuerte', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (237, N'Guamúchil', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (238, N'Escuinapa', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (239, N'Rosario', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (240, N'Concordia', 24)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (241, N'Hermosillo', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (242, N'Ciudad Obregón', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (243, N'Nogales', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (244, N'Navojoa', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (245, N'Guaymas', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (246, N'San Luis Río Colorado', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (247, N'Agua Prieta', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (248, N'Caborca', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (249, N'Puerto Peñasco', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (250, N'Cananea', 25)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (251, N'Villahermosa', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (252, N'Cárdenas', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (253, N'Comalcalco', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (254, N'Huimanguillo', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (255, N'Macuspana', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (256, N'Cunduacán', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (257, N'Teapa', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (258, N'Jalpa de Méndez', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (259, N'Nacajuca', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (260, N'Paraíso', 26)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (261, N'Reynosa', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (262, N'Matamoros', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (263, N'Nuevo Laredo', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (264, N'Tampico', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (265, N'Victoria', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (266, N'Altamira', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (267, N'Madero', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (268, N'Río Bravo', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (269, N'Valle Hermoso', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (270, N'Miguel Alemán', 27)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (271, N'Tlaxcala', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (272, N'Apizaco', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (273, N'Huamantla', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (274, N'Zacatelco', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (275, N'Chiautempan', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (276, N'Contla de Juan Cuamatzi', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (277, N'Panotla', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (278, N'Santa Cruz Tlaxcala', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (279, N'Tetla de la Solidaridad', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (280, N'Teolocholco', 28)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (281, N'Veracruz', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (282, N'Xalapa', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (283, N'Coatzacoalcos', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (284, N'Córdoba', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (285, N'Poza Rica', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (286, N'Orizaba', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (287, N'Minatitlán', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (288, N'Boca del Río', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (289, N'Tuxpan', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (290, N'Papantla', 29)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (291, N'Mérida', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (292, N'Valladolid', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (293, N'Tizimín', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (294, N'Progreso', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (295, N'Motul', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (296, N'Tekax', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (297, N'Izamal', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (298, N'Ticul', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (299, N'Umán', 30)
GO

-- %%
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (300, N'Kanasín', 30)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (301, N'Zacatecas', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (302, N'Fresnillo', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (303, N'Guadalupe', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (304, N'Jerez', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (305, N'Río Grande', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (306, N'Sombrerete', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (307, N'Ojocaliente', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (308, N'Tlaltenango', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (309, N'Pinos', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (310, N'Loreto', 31)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (311, N'Álvaro Obregón', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (312, N'Azcapotzalco', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (313, N'Benito Juárez', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (314, N'Coyoacán', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (315, N'Cuajimalpa', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (316, N'Gustavo A. Madero', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (317, N'Iztacalco', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (318, N'Iztapalapa', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (319, N'Magdalena Contreras', 32)
INSERT [dbo].[ciudades] ([id], [nombre], [estados_id]) VALUES (320, N'Miguel Hidalgo', 32)
SET IDENTITY_INSERT [dbo].[ciudades] OFF
GO

-- %% [markdown]
-- # [dbo].[colonias]

-- %%
SET IDENTITY_INSERT [dbo].[colonias] ON 
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (1, N'Centro Histórico', 121, N'CH-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (2, N'Americana', 121, N'AM-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (3, N'Providencia', 121, N'PROV-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (4, N'Chapultepec', 121, N'CHAP-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (5, N'Vallarta Norte', 121, N'VN-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (6, N'Jardines del Bosque', 121, N'JB-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (7, N'Chapalita', 121, N'CHA-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (8, N'Santa Teresita', 121, N'ST-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (9, N'Arcos Vallarta', 121, N'AV-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (10, N'Colinas de San Javier', 121, N'CSJ-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (11, N'Las Águilas', 121, N'LA-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (12, N'Residencial Victoria', 121, N'RV-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (13, N'Monraz', 121, N'MON-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (14, N'Zona Rosa', 121, N'ZR-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (15, N'Del Valle', 121, N'DV-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (16, N'Constitución', 121, N'CONST-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (17, N'Oblatos', 121, N'OBL-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (18, N'Huentitán', 121, N'HUEN-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (19, N'Minerva', 121, N'MIN-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (20, N'Miravalle', 121, N'MIR-GDL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (21, N'Zapopan Centro', 122, N'ZC-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (22, N'Puerta de Hierro', 122, N'PH-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (23, N'Residencial Poniente', 122, N'RP-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (24, N'Ciudad Granja', 122, N'CG-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (25, N'Lomas del Valle', 122, N'LV-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (26, N'Real de Tesistán', 122, N'RT-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (27, N'Miramar', 122, N'MIR-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (28, N'La Calma', 122, N'LC-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (29, N'Arboledas', 122, N'ARB-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (30, N'Tabachines', 122, N'TAB-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (31, N'Bosques de la Victoria', 122, N'BV-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (32, N'Villa Universitaria', 122, N'VU-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (33, N'Prados Providencia', 122, N'PP-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (34, N'Nuevo México', 122, N'NM-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (35, N'Francisco I. Madero', 122, N'FIM-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (36, N'Lomas de Zapopan', 122, N'LZ-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (37, N'Parques de Tesistán', 122, N'PT-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (38, N'Mesa Colorada', 122, N'MC-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (39, N'San Juan de Ocotán', 122, N'SJO-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (40, N'Nextipac', 122, N'NEX-ZAP')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (41, N'Centro', 101, N'CEN-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (42, N'Jardines de Jerez', 101, N'JJ-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (43, N'San Miguel', 101, N'SM-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (44, N'La Martinica', 101, N'MAR-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (45, N'Los Paraísos', 101, N'LP-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (46, N'Residencial Campestre', 101, N'RC-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (47, N'Valle del Campestre', 101, N'VC-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (48, N'Hidalgo', 101, N'HID-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (49, N'Del Recreo', 101, N'DR-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (50, N'La Floresta', 101, N'FLO-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (51, N'Lomas del Campestre', 101, N'LC-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (52, N'Panorama', 101, N'PAN-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (53, N'San Felipe de Jesús', 101, N'SFJ-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (54, N'Piletas', 101, N'PIL-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (55, N'Bellavista', 101, N'BV-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (56, N'Azteca', 101, N'AZT-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (57, N'Santa Ana del Conde', 101, N'SAC-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (58, N'Villa de Guadalupe', 101, N'VG-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (59, N'Pedregal de Haciendas', 101, N'PH-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (60, N'Las Torres', 101, N'LT-LEO')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (61, N'Centro de Monterrey', 181, N'CM-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (62, N'Santa Catarina', 181, N'SC-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (63, N'Obispado', 181, N'OB-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (64, N'Mitras Centro', 181, N'MC-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (65, N'Del Valle', 181, N'DV-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (66, N'Roma', 181, N'ROM-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (67, N'Industrial', 181, N'IND-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (68, N'Moderna', 181, N'MOD-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (69, N'Buenos Aires', 181, N'BA-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (70, N'Residencial San Agustín', 181, N'RSA-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (71, N'Contry', 181, N'CON-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (72, N'Cumbres', 181, N'CUM-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (73, N'Linda Vista', 181, N'LV-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (74, N'Mirador', 181, N'MIR-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (75, N'Independencia', 181, N'IND-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (76, N'Doctores', 181, N'DOC-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (77, N'Terminal', 181, N'TER-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (78, N'Ancira', 181, N'ANC-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (79, N'Cerro de la Silla', 181, N'CS-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (80, N'Apodaca Centro', 181, N'AC-MTY')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (81, N'Centro Histórico', 201, N'CH-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (82, N'La Paz', 201, N'LP-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (83, N'Angelópolis', 201, N'ANG-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (84, N'Jardines de San Manuel', 201, N'JSM-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (85, N'Bosques de Angelópolis', 201, N'BA-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (86, N'San Jerónimo Caleras', 201, N'SJC-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (87, N'Zavaleta', 201, N'ZAV-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (88, N'Universidad', 201, N'UNI-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (89, N'Agua Santa', 201, N'AS-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (90, N'El Carmen', 201, N'EC-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (91, N'Bugambilias', 201, N'BUG-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (92, N'Villa Carmel', 201, N'VC-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (93, N'Flor del Bosque', 201, N'FB-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (94, N'Santa Cruz Buenavista', 201, N'SCB-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (95, N'Granjas San Isidro', 201, N'GSI-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (96, N'Cleotilde Torres', 201, N'CT-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (97, N'Bosques de San Sebastián', 201, N'BSS-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (98, N'Maravillas', 201, N'MAR-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (99, N'Villa Frontera', 201, N'VF-PUE')
GO

-- %%
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (100, N'Real de San Andrés', 201, N'RSA-PUE')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (101, N'Zona Centro', 21, N'ZC-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (102, N'Zona Río', 21, N'ZR-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (103, N'Playas de Tijuana', 21, N'PT-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (104, N'La Mesa', 21, N'LM-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (105, N'Otay', 21, N'OT-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (106, N'Libertad', 21, N'LIB-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (107, N'Cacho', 21, N'CAC-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (108, N'Hipódromo', 21, N'HIP-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (109, N'Chapultepec', 21, N'CHA-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (110, N'Camino Verde', 21, N'CV-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (111, N'Villa Fontana', 21, N'VF-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (112, N'Las Palmas', 21, N'LP-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (113, N'Lomas de Agua Caliente', 21, N'LAC-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (114, N'Colinas de California', 21, N'CC-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (115, N'Reforma', 21, N'REF-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (116, N'Buenaventura', 21, N'BV-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (117, N'Soler', 21, N'SOL-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (118, N'Aviación', 21, N'AV-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (119, N'Mariano Matamoros', 21, N'MM-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (120, N'Alemán', 21, N'ALE-TIJ')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (121, N'Centro Histórico', 301, N'CH-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (122, N'García Ginerés', 301, N'GG-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (123, N'Itzimná', 301, N'ITZ-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (124, N'México', 301, N'MEX-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (125, N'Buenavista', 301, N'BV-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (126, N'Campestre', 301, N'CAM-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (127, N'San José Tecoh', 301, N'SJT-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (128, N'Francisco de Montejo', 301, N'FM-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (129, N'Montes de Amé', 301, N'MA-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (130, N'Residencial Colonia México', 301, N'RCM-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (131, N'Pedregales de Tanlum', 301, N'PT-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (132, N'Dzityá', 301, N'DZI-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (133, N'Chuburná', 301, N'CHU-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (134, N'Altabrisa', 301, N'ALT-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (135, N'Las Américas', 301, N'LA-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (136, N'Benito Juárez Norte', 301, N'BJN-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (137, N'San Antonio Cinta', 301, N'SAC-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (138, N'Vergel', 301, N'VER-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (139, N'Salvador Alvarado Sur', 301, N'SAS-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (140, N'Sodzil Norte', 301, N'SN-MER')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (141, N'Centro', 221, N'CEN-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (142, N'Zona Hotelera', 221, N'ZH-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (143, N'SM 21', 221, N'SM21-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (144, N'SM 23', 221, N'SM23-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (145, N'SM 25', 221, N'SM25-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (146, N'SM 77', 221, N'SM77-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (147, N'Residencial Cumbres', 221, N'RC-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (148, N'Las Américas', 221, N'LA-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (149, N'Supermanzana 29', 221, N'SM29-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (150, N'Supermanzana 50', 221, N'SM50-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (151, N'Puerto Juárez', 221, N'PJ-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (152, N'Región 100', 221, N'R100-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (153, N'Región 240', 221, N'R240-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (154, N'Alfredo V. Bonfil', 221, N'AVB-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (155, N'Ciudad Caucel', 221, N'CC-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (156, N'Villas Otoch Paraíso', 221, N'VOP-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (157, N'Gran Santa Fe', 221, N'GSF-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (158, N'Residencial Palmaris', 221, N'RP-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (159, N'Jardines del Sur', 221, N'JS-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (160, N'Paraíso Maya', 221, N'PM-CUN')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (161, N'Centro', 141, N'CEN-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (162, N'La Merced', 141, N'LM-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (163, N'Universidad', 141, N'UNI-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (164, N'Delegación San Lorenzo', 141, N'DSL-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (165, N'Capultitlán', 141, N'CAP-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (166, N'Seminario', 141, N'SEM-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (167, N'Santa Ana Tlapaltitlán', 141, N'SAT-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (168, N'Doctores', 141, N'DOC-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (169, N'Morelos', 141, N'MOR-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (170, N'5 de Mayo', 141, N'5M-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (171, N'Otzacatipan', 141, N'OTZ-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (172, N'Santa Clara', 141, N'SC-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (173, N'Pilares', 141, N'PIL-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (174, N'Las Torres', 141, N'LT-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (175, N'Residencial Colón', 141, N'RC-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (176, N'Adolfo López Mateos', 141, N'ALM-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (177, N'Benito Juárez', 141, N'BJ-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (178, N'Nueva Oxtotitlán', 141, N'NO-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (179, N'Felipe Berriozábal', 141, N'FB-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (180, N'San Bernardino', 141, N'SB-TOL')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (181, N'Centro', 61, N'CEN-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (182, N'Nombre de Dios', 61, N'ND-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (183, N'San Felipe', 61, N'SF-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (184, N'Granjas', 61, N'GRA-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (185, N'Campestre', 61, N'CAM-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (186, N'Cerro de la Cruz', 61, N'CC-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (187, N'Dale', 61, N'DAL-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (188, N'Las Haciendas', 61, N'LH-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (189, N'Riberas de Sacramento', 61, N'RS-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (190, N'Villa Juárez', 61, N'VJ-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (191, N'Satelite', 61, N'SAT-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (192, N'Quintas del Sol', 61, N'QS-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (193, N'Los Nogales', 61, N'LN-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (194, N'Rincones de San Marcos', 61, N'RSM-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (195, N'San Patricio', 61, N'SP-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (196, N'Mirador', 61, N'MIR-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (197, N'Residencial Universidad', 61, N'RU-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (198, N'Chula Vista', 61, N'CV-CHI')
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (199, N'Altavista', 61, N'AV-CHI')
GO

-- %%
INSERT [dbo].[colonias] ([id], [nombre], [ciudad_id], [abrevCiudad]) VALUES (200, N'Las Misiones', 61, N'LM-CHI')
SET IDENTITY_INSERT [dbo].[colonias] OFF
GO

-- %% [markdown]
-- # [dbo].[estados]

-- %%
SET IDENTITY_INSERT [dbo].[estados] ON 
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (1, N'Aguascalientes', N'AGS')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (2, N'Baja California', N'BC')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (3, N'Baja California Sur', N'BCS')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (4, N'Campeche', N'CAM')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (5, N'Chiapas', N'CHIS')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (6, N'Chihuahua', N'CHIH')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (7, N'Coahuila', N'COAH')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (8, N'Colima', N'COL')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (9, N'Durango', N'DGO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (10, N'Guanajuato', N'GTO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (11, N'Guerrero', N'GRO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (12, N'Hidalgo', N'HGO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (13, N'Jalisco', N'JAL')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (14, N'México', N'MEX')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (15, N'Michoacán', N'MICH')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (16, N'Morelos', N'MOR')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (17, N'Nayarit', N'NAY')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (18, N'Nuevo León', N'NL')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (19, N'Oaxaca', N'OAX')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (20, N'Puebla', N'PUE')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (21, N'Querétaro', N'QRO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (22, N'Quintana Roo', N'QROO')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (23, N'San Luis Potosí', N'SLP')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (24, N'Sinaloa', N'SIN')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (25, N'Sonora', N'SON')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (26, N'Tabasco', N'TAB')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (27, N'Tamaulipas', N'TAMPS')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (28, N'Tlaxcala', N'TLAX')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (29, N'Veracruz', N'VER')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (30, N'Yucatán', N'YUC')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (31, N'Zacatecas', N'ZAC')
INSERT [dbo].[estados] ([id], [nombre], [abreviatura]) VALUES (32, N'Ciudad de México', N'CDMX')
SET IDENTITY_INSERT [dbo].[estados] OFF
GO

-- %% [markdown]
-- # [dbo].[paquetes]

-- %%
SET IDENTITY_INSERT [dbo].[paquetes] ON 
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (1, N'Dúo Básico', N'Paquete básico que incluye Internet 50MB + Cable Básico. Ideal para hogares pequeños con necesidades básicas de entretenimiento y navegación.', CAST(649.00 AS Decimal(10, 2)), CAST(8.00 AS Decimal(5, 2)), 1)
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (2, N'Dúo Premium', N'Paquete premium con Internet 200MB + Cable Premium. Perfecto para familias que disfrutan del streaming y canales HD.', CAST(1299.00 AS Decimal(10, 2)), CAST(12.00 AS Decimal(5, 2)), 1)
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (3, N'Triple Play Básico', N'Paquete completo con Internet 100MB + Cable Estándar + Línea Telefónica. La solución integral para el hogar moderno.', CAST(1099.00 AS Decimal(10, 2)), CAST(15.00 AS Decimal(5, 2)), 1)
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (4, N'Triple Play Premium', N'Paquete premium con Internet 500MB + Cable Elite + Línea Telefónica. Para familias exigentes que requieren la mejor experiencia.', CAST(1899.00 AS Decimal(10, 2)), CAST(18.00 AS Decimal(5, 2)), 1)
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (5, N'Paquete Empresarial', N'Solución empresarial con Internet 1GB + Cable Básico + Línea Telefónica + Soporte Técnico Premium. Diseñado para pequeñas y medianas empresas.', CAST(2499.00 AS Decimal(10, 2)), CAST(10.00 AS Decimal(5, 2)), 1)
INSERT [dbo].[paquetes] ([id], [nombre], [descripcion], [precio_total], [descuento_porcentaje], [activo]) VALUES (6, N'Paquete Estudiante', N'Paquete económico con Internet 100MB + Cable Familiar + Línea Telefónica. Especial para estudiantes y familias jóvenes.', CAST(899.00 AS Decimal(10, 2)), CAST(20.00 AS Decimal(5, 2)), 1)
SET IDENTITY_INSERT [dbo].[paquetes] OFF
GO

-- %% [markdown]
-- # [dbo].[servicios]

-- %%
SET IDENTITY_INSERT [dbo].[servicios] ON 
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (1, N'Internet Básico 50MB', 1, N'50 Mbps', CAST(399.00 AS Decimal(10, 2)), N'Plan básico de internet ideal para navegación web y redes sociales', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (2, N'Internet Estándar 100MB', 1, N'100 Mbps', CAST(599.00 AS Decimal(10, 2)), N'Plan estándar perfecto para streaming y trabajo desde casa', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (3, N'Internet Premium 200MB', 1, N'200 Mbps', CAST(899.00 AS Decimal(10, 2)), N'Plan premium para familias numerosas y uso intensivo', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (4, N'Internet Pro 500MB', 1, N'500 Mbps', CAST(1299.00 AS Decimal(10, 2)), N'Plan profesional para empresas y gamers exigentes', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (5, N'Internet Ultra 1GB', 1, N'1 Gbps', CAST(1999.00 AS Decimal(10, 2)), N'Máxima velocidad disponible para uso comercial y streaming 4K', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (6, N'Cable Básico', 2, NULL, CAST(299.00 AS Decimal(10, 2)), N'Paquete básico con 80+ canales nacionales e internacionales', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (7, N'Cable Estándar', 2, NULL, CAST(399.00 AS Decimal(10, 2)), N'Paquete estándar con 120+ canales incluyendo canales HD', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (8, N'Cable Premium', 2, NULL, CAST(549.00 AS Decimal(10, 2)), N'Paquete premium con 180+ canales HD y canales deportivos', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (9, N'Cable Elite', 2, NULL, CAST(699.00 AS Decimal(10, 2)), N'Paquete elite con todos los canales premium y HBO', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (10, N'Cable Deportivo', 2, NULL, CAST(799.00 AS Decimal(10, 2)), N'Paquete especializado en deportes con ESPN, Fox Sports y más', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (11, N'Cable Familiar', 2, NULL, CAST(449.00 AS Decimal(10, 2)), N'Paquete familiar con canales infantiles, educativos y entretenimiento', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (12, N'Línea Telefónica Ilimitada', 3, NULL, CAST(249.00 AS Decimal(10, 2)), N'Servicio de telefonía fija con llamadas nacionales ilimitadas', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (13, N'Plan Móvil Básico 3GB', 4, N'4G LTE', CAST(299.00 AS Decimal(10, 2)), N'Plan móvil básico con 3GB de datos y llamadas ilimitadas', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (14, N'Plan Móvil Estándar 8GB', 4, N'4G LTE', CAST(449.00 AS Decimal(10, 2)), N'Plan móvil estándar con 8GB de datos y redes sociales gratis', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (15, N'Plan Móvil Premium 15GB', 4, N'4G/5G', CAST(649.00 AS Decimal(10, 2)), N'Plan premium con 15GB de datos y streaming de música gratis', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (16, N'Plan Móvil Ilimitado', 4, N'5G', CAST(899.00 AS Decimal(10, 2)), N'Plan ilimitado con datos sin límite y velocidad 5G', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (17, N'Instalación Básica', 5, NULL, CAST(199.00 AS Decimal(10, 2)), N'Servicio de instalación básica de equipos y configuración inicial', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (18, N'Soporte Técnico Premium', 5, NULL, CAST(399.00 AS Decimal(10, 2)), N'Soporte técnico 24/7 con visitas a domicilio incluidas', 1)
INSERT [dbo].[servicios] ([id], [nombre], [tipo_servicio_id], [velocidad], [precio_base], [descripcion], [activo]) VALUES (19, N'Mantenimiento Preventivo', 5, NULL, CAST(299.00 AS Decimal(10, 2)), N'Servicio de mantenimiento preventivo trimestral de equipos', 1)
SET IDENTITY_INSERT [dbo].[servicios] OFF
GO

-- %% [markdown]
-- # [dbo].[suscriptores]

-- %%
SET IDENTITY_INSERT [dbo].[suscriptores] ON 
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (1, N'Juan Carlos Pérez Hernández', N'JC', 121, 1, 13, N'juan.perez@email.com', N'3331234567', 1)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (2, N'Comercializadora ABC S.A. de C.V.', N'ABC Corp', 122, 21, 13, N'contacto@abccorp.com.mx', N'3339876543', 2)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (3, N'María Elena González López', N'Mari', 121, 5, 13, N'maria.gonzalez@megacable.com', N'3335555432', 3)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (4, N'Fundación Niños Felices A.C.', N'Fundación NF', 122, 25, 13, N'admin@ninosfelices.org', N'3337778899', 4)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (5, N'Ayuntamiento de Guadalajara', N'H. Ayto GDL', 121, 1, 13, N'sistemas@guadalajara.gob.mx', N'3336661122', 5)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (6, N'Instituto Tecnológico Superior', N'ITS Campus', 121, 8, 13, N'direccion@its.edu.mx', N'3334445566', 6)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (7, N'Casa Hogar San José A.C.', N'Casa SJ', 122, 30, 13, N'contacto@casasanjose.org', N'3332223344', 7)
INSERT [dbo].[suscriptores] ([id], [nombre], [alias], [ciudad_id], [colonia_id], [estados_id], [correo ], [celular], [tipo_suscriptor_id]) VALUES (8, N'Roberto Silva Martínez', N'Rob Silva', 121, 12, 13, N'roberto.silva@megacable.com', N'3338887766', 8)
SET IDENTITY_INSERT [dbo].[suscriptores] OFF
GO

-- %% [markdown]
-- # [dbo].[tipos_servicios]

-- %%
SET IDENTITY_INSERT [dbo].[tipos_servicios] ON 
INSERT [dbo].[tipos_servicios] ([id], [sku], [nombre], [descripcion], [activo]) VALUES (1, N'INET', N'Internet', N'Servicios de conexión a internet de alta velocidad con diferentes velocidades y planes', 1)
INSERT [dbo].[tipos_servicios] ([id], [sku], [nombre], [descripcion], [activo]) VALUES (2, N'CATV', N'Cable', N'Servicios de televisión por cable con canales HD, premium y paquetes deportivos', 1)
INSERT [dbo].[tipos_servicios] ([id], [sku], [nombre], [descripcion], [activo]) VALUES (3, N'FONE', N'Telefonía', N'Servicios de telefonía fija con llamadas locales, nacionales e internacionales', 1)
INSERT [dbo].[tipos_servicios] ([id], [sku], [nombre], [descripcion], [activo]) VALUES (4, N'MOBILE', N'Telefonía Móvil', N'Servicios de telefonía celular con planes de datos, voz y mensajería', 1)
INSERT [dbo].[tipos_servicios] ([id], [sku], [nombre], [descripcion], [activo]) VALUES (5, N'SUPPORT', N'Soporte Técnico', N'Servicios de soporte técnico especializado, instalación y mantenimiento', 1)
SET IDENTITY_INSERT [dbo].[tipos_servicios] OFF
GO

-- %% [markdown]
-- # [dbo].[tipos_suscriptores]

-- %%
SET IDENTITY_INSERT [dbo].[tipos_suscriptores] ON 
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (1, N'RES', N'Casa Habitacional', N'Suscriptores residenciales para uso doméstico familiar', CAST(0.00 AS Decimal(5, 2)), 0, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (2, N'EMP', N'Empresas', N'Empresas privadas, comercios y negocios', CAST(5.00 AS Decimal(5, 2)), 1, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (3, N'EMPL', N'Empleados', N'Empleados de la empresa con descuento especial', CAST(15.00 AS Decimal(5, 2)), 0, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (4, N'AC', N'Asociaciones Civiles', N'Organizaciones sin fines de lucro y asociaciones civiles', CAST(25.00 AS Decimal(5, 2)), 1, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (5, N'GOB', N'Gobierno Público', N'Dependencias gubernamentales y oficinas públicas', CAST(12.00 AS Decimal(5, 2)), 1, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (6, N'ESC', N'Escuelas', N'Instituciones educativas públicas y privadas', CAST(20.00 AS Decimal(5, 2)), 1, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (7, N'CARIDAD', N'Donaciones Caridad', N'Organizaciones benéficas y de asistencia social', CAST(30.00 AS Decimal(5, 2)), 1, 1)
INSERT [dbo].[tipos_suscriptores] ([id], [codigo], [nombre], [descripcion], [descuento_porcentaje], [requiere_contrato_especial], [activo]) VALUES (8, N'INTERNO', N'Cliente Interno', N'Personal interno de la empresa y familiares', CAST(50.00 AS Decimal(5, 2)), 0, 1)
SET IDENTITY_INSERT [dbo].[tipos_suscriptores] OFF
GO

-- %% [markdown]
-- # [UQ__contrato__79CE842A0CE39612]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__contrato__79CE842A0CE39612]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[contratos] ADD UNIQUE NONCLUSTERED 
(
	[numero_contrato] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__facturas__3DC4B241262EEAAB]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__facturas__3DC4B241262EEAAB]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[facturas] ADD UNIQUE NONCLUSTERED 
(
	[numero_factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__paquetes__862A201466CC0F5B]

-- %%
/****** Object:  Index [UQ__paquetes__862A201466CC0F5B]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[paquetes_servicios] ADD UNIQUE NONCLUSTERED 
(
	[paquete_id] ASC,
	[servicio_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [uq_suscriptores_celular_correo]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [uq_suscriptores_celular_correo]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[suscriptores] ADD  CONSTRAINT [uq_suscriptores_celular_correo] UNIQUE NONCLUSTERED 
(
	[celular] ASC,
	[correo ] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [uq_suscriptores_nombre_correo]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [uq_suscriptores_nombre_correo]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[suscriptores] ADD  CONSTRAINT [uq_suscriptores_nombre_correo] UNIQUE NONCLUSTERED 
(
	[nombre] ASC,
	[correo ] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__tipos_su__40F9A2063FBF91B0]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__tipos_su__40F9A2063FBF91B0]    Script Date: 24/06/2025 04:03:22 p. m. ******/
ALTER TABLE [dbo].[tipos_suscriptores] ADD UNIQUE NONCLUSTERED 
(
	[codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__contratos__estad__0A9D95DB]

-- %%
ALTER TABLE [dbo].[contratos] ADD  DEFAULT ('ACTIVO') FOR [estado]
GO

-- %% [markdown]
-- # [DF__contratos__creat__0B91BA14]

-- %%
ALTER TABLE [dbo].[contratos] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__contratos__fecha__160F4887]

-- %%
ALTER TABLE [dbo].[contratos_promociones] ADD  DEFAULT (getdate()) FOR [fecha_aplicacion]
GO

-- %% [markdown]
-- # [DF__contratos__activ__17036CC0]

-- %%
ALTER TABLE [dbo].[contratos_promociones] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [DEFAULT_contratos_servicios_descuento]

-- %%
ALTER TABLE [dbo].[contratos_servicios] ADD  CONSTRAINT [DEFAULT_contratos_servicios_descuento]  DEFAULT ((0.00)) FOR [descuento]
GO

-- %% [markdown]
-- # [DF__contratos__estad__114A936A]

-- %%
ALTER TABLE [dbo].[contratos_servicios] ADD  DEFAULT ('ACTIVO') FOR [estado]
GO

-- %% [markdown]
-- # [DF__facturas__descue__1BC821DD]

-- %%
ALTER TABLE [dbo].[facturas] ADD  DEFAULT ((0)) FOR [descuentos]
GO

-- %% [markdown]
-- # [DF__facturas__impues__1CBC4616]

-- %%
ALTER TABLE [dbo].[facturas] ADD  DEFAULT ((0)) FOR [impuestos]
GO

-- %% [markdown]
-- # [DF__facturas__estado__1DB06A4F]

-- %%
ALTER TABLE [dbo].[facturas] ADD  DEFAULT ('PENDIENTE') FOR [estado]
GO

-- %% [markdown]
-- # [DF__facturas__fecha___1EA48E88]

-- %%
ALTER TABLE [dbo].[facturas] ADD  DEFAULT (getdate()) FOR [fecha_emision]
GO

-- %% [markdown]
-- # [DF__pagos__fecha_pag__22751F6C]

-- %%
ALTER TABLE [dbo].[pagos] ADD  DEFAULT (getdate()) FOR [fecha_pago]
GO

-- %% [markdown]
-- # [DF__pagos__estado__236943A5]

-- %%
ALTER TABLE [dbo].[pagos] ADD  DEFAULT ('COMPLETADO') FOR [estado]
GO

-- %% [markdown]
-- # [DF__paquetes__descue__7A672E12]

-- %%
ALTER TABLE [dbo].[paquetes] ADD  DEFAULT ((0)) FOR [descuento_porcentaje]
GO

-- %% [markdown]
-- # [DF__paquetes__activo__7B5B524B]

-- %%
ALTER TABLE [dbo].[paquetes] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [DF__paquetes___canti__01142BA1]

-- %%
ALTER TABLE [dbo].[paquetes_servicios] ADD  DEFAULT ((1)) FOR [cantidad]
GO

-- %% [markdown]
-- # [DF__promocion__es_po__03F0984C]

-- %%
ALTER TABLE [dbo].[promociones] ADD  DEFAULT ((0)) FOR [es_porcentaje]
GO

-- %% [markdown]
-- # [DF__promocion__durac__04E4BC85]

-- %%
ALTER TABLE [dbo].[promociones] ADD  DEFAULT ((1)) FOR [duracion_meses]
GO

-- %% [markdown]
-- # [DF__promocion__activ__05D8E0BE]

-- %%
ALTER TABLE [dbo].[promociones] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [DF__servicios__activ__778AC167]

-- %%
ALTER TABLE [dbo].[servicios] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [DF__tipos_ser__activ__73BA3083]

-- %%
ALTER TABLE [dbo].[tipos_servicios] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [DF__tipos_sus__descu__5DCAEF64]

-- %%
ALTER TABLE [dbo].[tipos_suscriptores] ADD  DEFAULT ((0)) FOR [descuento_porcentaje]
GO

-- %% [markdown]
-- # [DF__tipos_sus__requi__5EBF139D]

-- %%
ALTER TABLE [dbo].[tipos_suscriptores] ADD  DEFAULT ((0)) FOR [requiere_contrato_especial]
GO

-- %% [markdown]
-- # [DF__tipos_sus__activ__5FB337D6]

-- %%
ALTER TABLE [dbo].[tipos_suscriptores] ADD  DEFAULT ((1)) FOR [activo]
GO

-- %% [markdown]
-- # [FK__ciudades__estado__4222D4EF]

-- %%
ALTER TABLE [dbo].[ciudades]  WITH CHECK ADD FOREIGN KEY([estados_id])
REFERENCES [dbo].[estados] ([id])
GO

-- %% [markdown]
-- # [FK__colonias__ciudad__44FF419A]

-- %%
ALTER TABLE [dbo].[colonias]  WITH CHECK ADD FOREIGN KEY([ciudad_id])
REFERENCES [dbo].[ciudades] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__suscr__09A971A2]

-- %%
ALTER TABLE [dbo].[contratos]  WITH CHECK ADD FOREIGN KEY([suscriptor_id])
REFERENCES [dbo].[suscriptores] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__contr__14270015]

-- %%
ALTER TABLE [dbo].[contratos_promociones]  WITH CHECK ADD FOREIGN KEY([contrato_id])
REFERENCES [dbo].[contratos] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__promo__151B244E]

-- %%
ALTER TABLE [dbo].[contratos_promociones]  WITH CHECK ADD FOREIGN KEY([promocion_id])
REFERENCES [dbo].[promociones] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__contr__0E6E26BF]

-- %%
ALTER TABLE [dbo].[contratos_servicios]  WITH CHECK ADD FOREIGN KEY([contrato_id])
REFERENCES [dbo].[contratos] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__paque__10566F31]

-- %%
ALTER TABLE [dbo].[contratos_servicios]  WITH CHECK ADD FOREIGN KEY([paquete_id])
REFERENCES [dbo].[paquetes] ([id])
GO

-- %% [markdown]
-- # [FK__contratos__servi__0F624AF8]

-- %%
ALTER TABLE [dbo].[contratos_servicios]  WITH CHECK ADD FOREIGN KEY([servicio_id])
REFERENCES [dbo].[servicios] ([id])
GO

-- %% [markdown]
-- # [FK__facturas__contra__1AD3FDA4]

-- %%
ALTER TABLE [dbo].[facturas]  WITH CHECK ADD FOREIGN KEY([contrato_id])
REFERENCES [dbo].[contratos] ([id])
GO

-- %% [markdown]
-- # [FK__pagos__factura_i__2180FB33]

-- %%
ALTER TABLE [dbo].[pagos]  WITH CHECK ADD FOREIGN KEY([factura_id])
REFERENCES [dbo].[facturas] ([id])
GO

-- %% [markdown]
-- # [FK__paquetes___paque__7F2BE32F]

-- %%
ALTER TABLE [dbo].[paquetes_servicios]  WITH CHECK ADD FOREIGN KEY([paquete_id])
REFERENCES [dbo].[paquetes] ([id])
GO

-- %% [markdown]
-- # [FK__paquetes___servi__00200768]

-- %%
ALTER TABLE [dbo].[paquetes_servicios]  WITH CHECK ADD FOREIGN KEY([servicio_id])
REFERENCES [dbo].[servicios] ([id])
GO

-- %% [markdown]
-- # [FK__servicios__tipo___76969D2E]

-- %%
ALTER TABLE [dbo].[servicios]  WITH CHECK ADD FOREIGN KEY([tipo_servicio_id])
REFERENCES [dbo].[tipos_servicios] ([id])
GO

-- %% [markdown]
-- # [FK__suscripto__ciuda__4AB81AF0]

-- %%
ALTER TABLE [dbo].[suscriptores]  WITH CHECK ADD FOREIGN KEY([ciudad_id])
REFERENCES [dbo].[ciudades] ([id])
GO

-- %% [markdown]
-- # [FK__suscripto__colon__4BAC3F29]

-- %%
ALTER TABLE [dbo].[suscriptores]  WITH CHECK ADD FOREIGN KEY([colonia_id])
REFERENCES [dbo].[colonias] ([id])
GO

-- %% [markdown]
-- # [FK__suscripto__estad__4CA06362]

-- %%
ALTER TABLE [dbo].[suscriptores]  WITH CHECK ADD FOREIGN KEY([estados_id])
REFERENCES [dbo].[estados] ([id])
GO

-- %% [markdown]
-- # [FK__suscripto__tipo___60A75C0F]

-- %%
ALTER TABLE [dbo].[suscriptores]  WITH CHECK ADD FOREIGN KEY([tipo_suscriptor_id])
REFERENCES [dbo].[tipos_suscriptores] ([id])
GO

-- %% [markdown]
-- # [CHK_descuento_maximo_10]

-- %%
ALTER TABLE [dbo].[contratos_servicios]  WITH CHECK ADD  CONSTRAINT [CHK_descuento_maximo_10] CHECK  (([descuento] IS NULL OR [descuento]>=(0.00) AND [descuento]<=(10.00)))
GO
ALTER TABLE [dbo].[contratos_servicios] CHECK CONSTRAINT [CHK_descuento_maximo_10]
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'descuento aplicado sobre el precio base ' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'contratos_servicios', @level2type=N'COLUMN',@level2name=N'descuento'
GO

-- %% [markdown]
-- # [PracticaMega]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PracticaMega] SET  READ_WRITE 
GO
